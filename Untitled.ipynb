# %%
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/documents.readonly',
          'https://www.googleapis.com/auth/drive',
          'https://www.googleapis.com/auth/drive.appdata']
# The ID of a sample document.
DOCUMENT_ID = '17nN5K6LFXGT5EA8dYVr2dfhk6ZhqdwF-bOXh8dVClAU'

# %%
creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'client_secret_688549307326-ba24onctnfdh6vdagtq48ijkppfepg4u.apps.googleusercontent.com.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

doc_service = build('docs', 'v1', credentials=creds)
drive_service = build('drive', 'v3', credentials=creds)

# %%
res = drive_service.files().get(fileId='1ljfytcSZi1d0er46Z7FxI5yL85QnAAoI').execute()

# %%
drive_service.files().list(q="'1ljfytcSZi1d0er46Z7FxI5yL85QnAAoI' in parents").execute()
# Out:
# {'kind': 'drive#fileList',
#  'incompleteSearch': False,
#  'files': [{'kind': 'drive#file',
#    'id': '1wpNa4NLIOtpEjiLIZjY7CWptpJe8qAAjSypKGd0qT2I',
#    'name': 'Untitled document',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '17nN5K6LFXGT5EA8dYVr2dfhk6ZhqdwF-bOXh8dVClAU',
#    'name': 'Daily Workflow November 4 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1tqRLyg7rFz1251JrrNTym9cv4HbyL7-vZqMYa1uTrfA',
#    'name': 'Daily Workflow November 3 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1HB1QSN_-d6UdagtEATH2hAGKbMZ4IkSulJopoZIRP-U',
#    'name': 'Daily Workflow November 2 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1-rghChCwWQOfIv9F7M5CP2XWBHVhpoLGjWDxIV7BidM',
#    'name': 'Daily Workflow October 31 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1iqR-UQO4xL_tAPPMijnRMfvmyfieWRNcuGjCojcVBDQ',
#    'name': 'Daily Workflow October 28 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1EPVbrA6uQxZCLq9E7Fv8n9ukyzUZdrriDyv9T2lT-1o',
#    'name': 'Daily Workflow October 27 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '186S5ovjP8C3Xb-En1HZED3WpS0urJ8TaEDc72NIESVM',
#    'name': 'Daily Workflow October 26 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1tXM_TdG1opbqudTKzkjm6dveAaIHtg-A5WJZaPiLSg4',
#    'name': 'Daily Workflow October 25 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1sZeTe3Jgc0yCWJjxf6puaq5TKb94c6aYRmxqkdn_O1g',
#    'name': 'Daily Workflow October 22 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1OZwyfmqMBjbOgCVbtksgf7X31vf_G3-OUDhEywK3ZBE',
#    'name': 'Daily Workflow October 21 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1arJGj7rXlQGQ38JqnqG4Cj4Rvw8fW6Z_BMMo2RRVGTY',
#    'name': 'Daily Workflow October 20 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '16DawH3v_TKTWUXxPDYNObvSc4MZC5pGZULzmZZNIyLI',
#    'name': 'Daily Workflow October 19 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1oTFIjIr_h0ZyVn8_IA0tweHZOxwS0o7gCAh_I60cKRI',
#    'name': 'Daily Workflow October 18 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1nXlS-qepoke_-b2NgK-ragMQHyBRZJtLhsYoDkCR2Iw',
#    'name': 'Daily Workflow October 15 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1kp67c0Y-siiays8JR5p8hTr33i2mzFtA8I3YrCI0k6w',
#    'name': 'Daily Workflow October 14 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1CsdCkoZhTF1aoZXDjlV6DZN3YJAVri9H6_FaHktVaaA',
#    'name': 'Daily Workflow October 13 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1o12hEVDwUZvzKohUz2KWC7MiEQlcoW4n44PGk-jCfmw',
#    'name': 'Daily Workflow October 12 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1oa6-ZCLvPgzj2e1SvAb7nGL7vWfBSgKAnZwV4ymg6TI',
#    'name': 'Daily Workflow October 11 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1P3e5JYAawCMt2zJOQWs0u9LZXsSaZY6LwVHyMKbrv_c',
#    'name': 'Daily Workflow October 10 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1f0KGMCt9NkOh6ED58y_7tewSBBRX9avQSTSu2J1cau4',
#    'name': 'Daily Workflow October 9 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1LBnVPIhlRCtgxAmF7dw20ZHrFQN6WayVXEa6AA0oNME',
#    'name': 'Daily Workflow October 8 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1l90qK7-f09mRdhRQyYSFr3fER6x01ik8Cw6UzNB8mh0',
#    'name': 'Daily Workflow October 7 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1nI99SMJaapKqSPGrYDVxQzkJNpQOxuIzaQggocISKP4',
#    'name': 'Daily Workflow October 6 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1qSDvojtbLjAdCztD6BVA39JDToPUHQz--rxzY-ytiJg',
#    'name': 'Daily Workflow October 5 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1H_Mx_U8M88F4MVmRm0a5oe28iJAw-N1VSPhUFFjN6aE',
#    'name': 'Daily Workflow October 4 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1zzWT6-aIjPBhd7SEeadfo6uDFeHSyF3poBw-Q9cRpN4',
#    'name': 'Daily Workflow October 1 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1gxyu4lr26MEFwo3nEek_Yf5CRsRfucNIQHJtVvAklHc',
#    'name': 'Daily Workflow September 30 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1wM_2YTWjcpzt2cdNY7bfiUcgkvxpDEOGmNHGAFii5eo',
#    'name': 'Daily Workflow September 29 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1EyoCIfo3VkJCpba9EX6CoH-jCz18rhV4Tbl6ngrkF6M',
#    'name': 'Daily Workflow September 28 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '11-qPoBd4rrhtUiKyV1Q4UTK1wHxlKA_zJ_9zRzo27Ow',
#    'name': 'Daily Workflow September 27 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1TY6nLyZztcac0-61DKVeZdVEjoXdHSJITKY7H2oHCNE',
#    'name': 'Daily Workflow September 24 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1mUP2gwXfulVdSXZk_4I5mRg8bDmfPnA3YqFIF1W9-hw',
#    'name': 'Daily Workflow September 23 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '12JKGi2SGJiMt6VultoNeV0Vc3gk8l7U9W87ElmglAN8',
#    'name': 'Daily Workflow September 22 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1GI2kwJNH0-tlbJQ-dc3-KHn_ON3DK2sxXbAuxw9eXNc',
#    'name': 'Daily Workflow September 21 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1GXuWamhA9E7hTW2RgUcCBl-W1y84sm-Aqa8_kyvN_SM',
#    'name': 'Daily Workflow September 20 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1Q644uNUW9FS7PlR3Jju7iaf8bv3CtTll4zqdKkUC5A0',
#    'name': 'Daily Workflow September 16 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1H2nbGS_srx7YOLAarJvHrURDmtgD64j4vSCY5NTMi84',
#    'name': 'Daily Workflow September 9 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '1alpHiTZM4_ryoMu4vEHApiKEJT3x6MVxMTiTPZgIYH8',
#    'name': 'Daily Workflow September 8 2021',
#    'mimeType': 'application/vnd.google-apps.document'},
#   {'kind': 'drive#file',
#    'id': '13oQaKT2fEHgk7t1BHT2Iwea6IcHV8PbBX0UkoQeKE-s',
#    'name': 'Daily Workflow September 7 2021',
#    'mimeType': 'application/vnd.google-apps.document'}]}

# %%
def get_all_files(folder_id='1ljfytcSZi1d0er46Z7FxI5yL85QnAAoI'):
    page_token = None
    files = []
    while True:
        response = drive_service.files().list(q=f"'{folder_id}' in parents",
                                              spaces='drive',
                                              fields='nextPageToken, files(id, name)',
                                              pageToken=page_token).execute()
        files.extend(response.get('files', []))
        for file in response.get('files', []):
            # Process change
            print('Found file: %s (%s)' % (file.get('name'), file.get('id')))
        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break
    return files

# %%
f = get_all_files()
# Out:
# Found file: Daily Workflow November 5 2021 (1wpNa4NLIOtpEjiLIZjY7CWptpJe8qAAjSypKGd0qT2I)
# Found file: Daily Workflow November 4 2021 (17nN5K6LFXGT5EA8dYVr2dfhk6ZhqdwF-bOXh8dVClAU)
# Found file: Daily Workflow November 3 2021 (1tqRLyg7rFz1251JrrNTym9cv4HbyL7-vZqMYa1uTrfA)
# Found file: Daily Workflow November 2 2021 (1HB1QSN_-d6UdagtEATH2hAGKbMZ4IkSulJopoZIRP-U)
# Found file: Daily Workflow October 31 2021 (1-rghChCwWQOfIv9F7M5CP2XWBHVhpoLGjWDxIV7BidM)
# Found file: Daily Workflow October 28 2021 (1iqR-UQO4xL_tAPPMijnRMfvmyfieWRNcuGjCojcVBDQ)
# Found file: Daily Workflow October 27 2021 (1EPVbrA6uQxZCLq9E7Fv8n9ukyzUZdrriDyv9T2lT-1o)
# Found file: Daily Workflow October 26 2021 (186S5ovjP8C3Xb-En1HZED3WpS0urJ8TaEDc72NIESVM)
# Found file: Daily Workflow October 25 2021 (1tXM_TdG1opbqudTKzkjm6dveAaIHtg-A5WJZaPiLSg4)
# Found file: Daily Workflow October 22 2021 (1sZeTe3Jgc0yCWJjxf6puaq5TKb94c6aYRmxqkdn_O1g)
# Found file: Daily Workflow October 21 2021 (1OZwyfmqMBjbOgCVbtksgf7X31vf_G3-OUDhEywK3ZBE)
# Found file: Daily Workflow October 20 2021 (1arJGj7rXlQGQ38JqnqG4Cj4Rvw8fW6Z_BMMo2RRVGTY)
# Found file: Daily Workflow October 19 2021 (16DawH3v_TKTWUXxPDYNObvSc4MZC5pGZULzmZZNIyLI)
# Found file: Daily Workflow October 18 2021 (1oTFIjIr_h0ZyVn8_IA0tweHZOxwS0o7gCAh_I60cKRI)
# Found file: Daily Workflow October 15 2021 (1nXlS-qepoke_-b2NgK-ragMQHyBRZJtLhsYoDkCR2Iw)
# Found file: Daily Workflow October 14 2021 (1kp67c0Y-siiays8JR5p8hTr33i2mzFtA8I3YrCI0k6w)
# Found file: Daily Workflow October 13 2021 (1CsdCkoZhTF1aoZXDjlV6DZN3YJAVri9H6_FaHktVaaA)
# Found file: Daily Workflow October 12 2021 (1o12hEVDwUZvzKohUz2KWC7MiEQlcoW4n44PGk-jCfmw)
# Found file: Daily Workflow October 11 2021 (1oa6-ZCLvPgzj2e1SvAb7nGL7vWfBSgKAnZwV4ymg6TI)
# Found file: Daily Workflow October 10 2021 (1P3e5JYAawCMt2zJOQWs0u9LZXsSaZY6LwVHyMKbrv_c)
# Found file: Daily Workflow October 9 2021 (1f0KGMCt9NkOh6ED58y_7tewSBBRX9avQSTSu2J1cau4)
# Found file: Daily Workflow October 8 2021 (1LBnVPIhlRCtgxAmF7dw20ZHrFQN6WayVXEa6AA0oNME)
# Found file: Daily Workflow October 7 2021 (1l90qK7-f09mRdhRQyYSFr3fER6x01ik8Cw6UzNB8mh0)
# Found file: Daily Workflow October 6 2021 (1nI99SMJaapKqSPGrYDVxQzkJNpQOxuIzaQggocISKP4)
# Found file: Daily Workflow October 5 2021 (1qSDvojtbLjAdCztD6BVA39JDToPUHQz--rxzY-ytiJg)
# Found file: Daily Workflow October 4 2021 (1H_Mx_U8M88F4MVmRm0a5oe28iJAw-N1VSPhUFFjN6aE)
# Found file: Daily Workflow October 1 2021 (1zzWT6-aIjPBhd7SEeadfo6uDFeHSyF3poBw-Q9cRpN4)
# Found file: Daily Workflow September 30 2021 (1gxyu4lr26MEFwo3nEek_Yf5CRsRfucNIQHJtVvAklHc)
# Found file: Daily Workflow September 29 2021 (1wM_2YTWjcpzt2cdNY7bfiUcgkvxpDEOGmNHGAFii5eo)
# Found file: Daily Workflow September 28 2021 (1EyoCIfo3VkJCpba9EX6CoH-jCz18rhV4Tbl6ngrkF6M)
# Found file: Daily Workflow September 27 2021 (11-qPoBd4rrhtUiKyV1Q4UTK1wHxlKA_zJ_9zRzo27Ow)
# Found file: Daily Workflow September 24 2021 (1TY6nLyZztcac0-61DKVeZdVEjoXdHSJITKY7H2oHCNE)
# Found file: Daily Workflow September 23 2021 (1mUP2gwXfulVdSXZk_4I5mRg8bDmfPnA3YqFIF1W9-hw)
# Found file: Daily Workflow September 22 2021 (12JKGi2SGJiMt6VultoNeV0Vc3gk8l7U9W87ElmglAN8)
# Found file: Daily Workflow September 21 2021 (1GI2kwJNH0-tlbJQ-dc3-KHn_ON3DK2sxXbAuxw9eXNc)
# Found file: Daily Workflow September 20 2021 (1GXuWamhA9E7hTW2RgUcCBl-W1y84sm-Aqa8_kyvN_SM)
# Found file: Daily Workflow September 16 2021 (1Q644uNUW9FS7PlR3Jju7iaf8bv3CtTll4zqdKkUC5A0)
# Found file: Daily Workflow September 9 2021 (1H2nbGS_srx7YOLAarJvHrURDmtgD64j4vSCY5NTMi84)
# Found file: Daily Workflow September 8 2021 (1alpHiTZM4_ryoMu4vEHApiKEJT3x6MVxMTiTPZgIYH8)
# Found file: Daily Workflow September 7 2021 (13oQaKT2fEHgk7t1BHT2Iwea6IcHV8PbBX0UkoQeKE-s)

# %%
def get_recent_workflows(days):
    return get_all_files()[:days]

# %%
recent_flows = get_recent_workflows(4)
# Out:
# Found file: Daily Workflow November 5 2021 (1wpNa4NLIOtpEjiLIZjY7CWptpJe8qAAjSypKGd0qT2I)
# Found file: Daily Workflow November 4 2021 (17nN5K6LFXGT5EA8dYVr2dfhk6ZhqdwF-bOXh8dVClAU)
# Found file: Daily Workflow November 3 2021 (1tqRLyg7rFz1251JrrNTym9cv4HbyL7-vZqMYa1uTrfA)
# Found file: Daily Workflow November 2 2021 (1HB1QSN_-d6UdagtEATH2hAGKbMZ4IkSulJopoZIRP-U)
# Found file: Daily Workflow October 31 2021 (1-rghChCwWQOfIv9F7M5CP2XWBHVhpoLGjWDxIV7BidM)
# Found file: Daily Workflow October 28 2021 (1iqR-UQO4xL_tAPPMijnRMfvmyfieWRNcuGjCojcVBDQ)
# Found file: Daily Workflow October 27 2021 (1EPVbrA6uQxZCLq9E7Fv8n9ukyzUZdrriDyv9T2lT-1o)
# Found file: Daily Workflow October 26 2021 (186S5ovjP8C3Xb-En1HZED3WpS0urJ8TaEDc72NIESVM)
# Found file: Daily Workflow October 25 2021 (1tXM_TdG1opbqudTKzkjm6dveAaIHtg-A5WJZaPiLSg4)
# Found file: Daily Workflow October 22 2021 (1sZeTe3Jgc0yCWJjxf6puaq5TKb94c6aYRmxqkdn_O1g)
# Found file: Daily Workflow October 21 2021 (1OZwyfmqMBjbOgCVbtksgf7X31vf_G3-OUDhEywK3ZBE)
# Found file: Daily Workflow October 20 2021 (1arJGj7rXlQGQ38JqnqG4Cj4Rvw8fW6Z_BMMo2RRVGTY)
# Found file: Daily Workflow October 19 2021 (16DawH3v_TKTWUXxPDYNObvSc4MZC5pGZULzmZZNIyLI)
# Found file: Daily Workflow October 18 2021 (1oTFIjIr_h0ZyVn8_IA0tweHZOxwS0o7gCAh_I60cKRI)
# Found file: Daily Workflow October 15 2021 (1nXlS-qepoke_-b2NgK-ragMQHyBRZJtLhsYoDkCR2Iw)
# Found file: Daily Workflow October 14 2021 (1kp67c0Y-siiays8JR5p8hTr33i2mzFtA8I3YrCI0k6w)
# Found file: Daily Workflow October 13 2021 (1CsdCkoZhTF1aoZXDjlV6DZN3YJAVri9H6_FaHktVaaA)
# Found file: Daily Workflow October 12 2021 (1o12hEVDwUZvzKohUz2KWC7MiEQlcoW4n44PGk-jCfmw)
# Found file: Daily Workflow October 11 2021 (1oa6-ZCLvPgzj2e1SvAb7nGL7vWfBSgKAnZwV4ymg6TI)
# Found file: Daily Workflow October 10 2021 (1P3e5JYAawCMt2zJOQWs0u9LZXsSaZY6LwVHyMKbrv_c)
# Found file: Daily Workflow October 9 2021 (1f0KGMCt9NkOh6ED58y_7tewSBBRX9avQSTSu2J1cau4)
# Found file: Daily Workflow October 8 2021 (1LBnVPIhlRCtgxAmF7dw20ZHrFQN6WayVXEa6AA0oNME)
# Found file: Daily Workflow October 7 2021 (1l90qK7-f09mRdhRQyYSFr3fER6x01ik8Cw6UzNB8mh0)
# Found file: Daily Workflow October 6 2021 (1nI99SMJaapKqSPGrYDVxQzkJNpQOxuIzaQggocISKP4)
# Found file: Daily Workflow October 5 2021 (1qSDvojtbLjAdCztD6BVA39JDToPUHQz--rxzY-ytiJg)
# Found file: Daily Workflow October 4 2021 (1H_Mx_U8M88F4MVmRm0a5oe28iJAw-N1VSPhUFFjN6aE)
# Found file: Daily Workflow October 1 2021 (1zzWT6-aIjPBhd7SEeadfo6uDFeHSyF3poBw-Q9cRpN4)
# Found file: Daily Workflow September 30 2021 (1gxyu4lr26MEFwo3nEek_Yf5CRsRfucNIQHJtVvAklHc)
# Found file: Daily Workflow September 29 2021 (1wM_2YTWjcpzt2cdNY7bfiUcgkvxpDEOGmNHGAFii5eo)
# Found file: Daily Workflow September 28 2021 (1EyoCIfo3VkJCpba9EX6CoH-jCz18rhV4Tbl6ngrkF6M)
# Found file: Daily Workflow September 27 2021 (11-qPoBd4rrhtUiKyV1Q4UTK1wHxlKA_zJ_9zRzo27Ow)
# Found file: Daily Workflow September 24 2021 (1TY6nLyZztcac0-61DKVeZdVEjoXdHSJITKY7H2oHCNE)
# Found file: Daily Workflow September 23 2021 (1mUP2gwXfulVdSXZk_4I5mRg8bDmfPnA3YqFIF1W9-hw)
# Found file: Daily Workflow September 22 2021 (12JKGi2SGJiMt6VultoNeV0Vc3gk8l7U9W87ElmglAN8)
# Found file: Daily Workflow September 21 2021 (1GI2kwJNH0-tlbJQ-dc3-KHn_ON3DK2sxXbAuxw9eXNc)
# Found file: Daily Workflow September 20 2021 (1GXuWamhA9E7hTW2RgUcCBl-W1y84sm-Aqa8_kyvN_SM)
# Found file: Daily Workflow September 16 2021 (1Q644uNUW9FS7PlR3Jju7iaf8bv3CtTll4zqdKkUC5A0)
# Found file: Daily Workflow September 9 2021 (1H2nbGS_srx7YOLAarJvHrURDmtgD64j4vSCY5NTMi84)
# Found file: Daily Workflow September 8 2021 (1alpHiTZM4_ryoMu4vEHApiKEJT3x6MVxMTiTPZgIYH8)
# Found file: Daily Workflow September 7 2021 (13oQaKT2fEHgk7t1BHT2Iwea6IcHV8PbBX0UkoQeKE-s)

# %%
recent_flows
# Out:
# [{'id': '1wpNa4NLIOtpEjiLIZjY7CWptpJe8qAAjSypKGd0qT2I',
#   'name': 'Daily Workflow November 5 2021'},
#  {'id': '17nN5K6LFXGT5EA8dYVr2dfhk6ZhqdwF-bOXh8dVClAU',
#   'name': 'Daily Workflow November 4 2021'},
#  {'id': '1tqRLyg7rFz1251JrrNTym9cv4HbyL7-vZqMYa1uTrfA',
#   'name': 'Daily Workflow November 3 2021'},
#  {'id': '1HB1QSN_-d6UdagtEATH2hAGKbMZ4IkSulJopoZIRP-U',
#   'name': 'Daily Workflow November 2 2021'}]

# %%
def get_doc(file_id):
     return doc_service.documents().get(documentId=file_id).execute()

# %%
docs = [get_doc(item['id']) for item in recent_flows]

# %%
docs
# Out:
# [{'title': 'Daily Workflow November 5 2021',
#   'body': {'content': [{'endIndex': 1,
#      'sectionBreak': {'sectionStyle': {'columnSeparatorStyle': 'NONE',
#        'contentDirection': 'LEFT_TO_RIGHT',
#        'sectionType': 'CONTINUOUS'}}},
#     {'startIndex': 1,
#      'endIndex': 32,
#      'paragraph': {'elements': [{'startIndex': 1,
#         'endIndex': 32,
#         'textRun': {'content': 'Daily Workflow November 5 2021\n',
#          'textStyle': {'bold': True,
#           'backgroundColor': {'color': {'rgbColor': {'red': 0.2901961,
#              'green': 0.5254902,
#              'blue': 0.9098039}}},
#           'foregroundColor': {'color': {'rgbColor': {'red': 1,
#              'green': 1,
#              'blue': 1}}},
#           'fontSize': {'magnitude': 24, 'unit': 'PT'}}}}],
#       'paragraphStyle': {'headingId': 'h.10qpii93ne17',
#        'namedStyleType': 'TITLE',
#        'alignment': 'CENTER',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 32,
#      'endIndex': 33,
#      'paragraph': {'elements': [{'startIndex': 32,
#         'endIndex': 33,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 33,
#      'endIndex': 37,
#      'paragraph': {'elements': [{'startIndex': 33,
#         'endIndex': 36,
#         'textRun': {'content': 'P0:',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1}}}}}},
#        {'startIndex': 36,
#         'endIndex': 37,
#         'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'headingId': 'h.t9wb2be2yvuu',
#        'namedStyleType': 'HEADING_2',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 37,
#      'endIndex': 54,
#      'paragraph': {'elements': [{'startIndex': 37,
#         'endIndex': 54,
#         'textRun': {'content': 'Tanuj Interview \n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.8dghcfksjel7', 'textStyle': {}}}},
#     {'startIndex': 54,
#      'endIndex': 98,
#      'paragraph': {'elements': [{'startIndex': 54,
#         'endIndex': 98,
#         'textRun': {'content': 'Update airflow certik-python to new version\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.8dghcfksjel7', 'textStyle': {}}}},
#     {'startIndex': 98,
#      'endIndex': 173,
#      'paragraph': {'elements': [{'startIndex': 98,
#         'endIndex': 122,
#         'textRun': {'content': 'Simple Flask Python app ', 'textStyle': {}}},
#        {'startIndex': 122,
#         'endIndex': 143,
#         'textRun': {'content': 'in docker to wrap the',
#          'textStyle': {'strikethrough': True}}},
#        {'startIndex': 143,
#         'endIndex': 144,
#         'textRun': {'content': ' ', 'textStyle': {}}},
#        {'startIndex': 144,
#         'endIndex': 173,
#         'textRun': {'content': 'semiautomatic labeling tool \n',
#          'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.1b7p1g77o21m', 'textStyle': {}}}},
#     {'startIndex': 173,
#      'endIndex': 225,
#      'paragraph': {'elements': [{'startIndex': 173,
#         'endIndex': 225,
#         'textRun': {'content': 'Switch cloud stored files into storing in snowflake\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.1b7p1g77o21m',
#        'nestingLevel': 1,
#        'textStyle': {}}}},
#     {'startIndex': 225,
#      'endIndex': 269,
#      'paragraph': {'elements': [{'startIndex': 225,
#         'endIndex': 268,
#         'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-459',
#          'textStyle': {'underline': True,
#           'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#              'green': 0.33333334,
#              'blue': 0.8}}},
#           'link': {'url': 'https://certik.atlassian.net/browse/WAT-459'}}}},
#        {'startIndex': 268,
#         'endIndex': 269,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.1b7p1g77o21m',
#        'nestingLevel': 1,
#        'textStyle': {}}}},
#     {'startIndex': 269,
#      'endIndex': 364,
#      'paragraph': {'elements': [{'startIndex': 269,
#         'endIndex': 283,
#         'textRun': {'content': 'Auto Labeling ', 'textStyle': {}}},
#        {'startIndex': 283,
#         'endIndex': 326,
#         'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-488',
#          'textStyle': {'underline': True,
#           'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#              'green': 0.33333334,
#              'blue': 0.8}}},
#           'link': {'url': 'https://certik.atlassian.net/browse/WAT-488'}}}},
#        {'startIndex': 326,
#         'endIndex': 364,
#         'textRun': {'content': 'Manuall labeling changed back to Andy\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.1b7p1g77o21m', 'textStyle': {}}}},
#     {'startIndex': 364,
#      'endIndex': 368,
#      'paragraph': {'elements': [{'startIndex': 364,
#         'endIndex': 367,
#         'textRun': {'content': 'P1:',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1,
#              'green': 0.6}}}}}},
#        {'startIndex': 367,
#         'endIndex': 368,
#         'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'headingId': 'h.9rqt2uhz0aq8',
#        'namedStyleType': 'HEADING_2',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 368,
#      'endIndex': 389,
#      'paragraph': {'elements': [{'startIndex': 368,
#         'endIndex': 388,
#         'textRun': {'content': 'Certik-python readme', 'textStyle': {}}},
#        {'startIndex': 388,
#         'endIndex': 389,
#         'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.53qqx1rmcjet', 'textStyle': {}}}},
#     {'startIndex': 389,
#      'endIndex': 428,
#      'paragraph': {'elements': [{'startIndex': 389,
#         'endIndex': 428,
#         'textRun': {'content': 'Learn about low level evm instructions\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.wrz2nfbs9sij', 'textStyle': {}}}},
#     {'startIndex': 428,
#      'endIndex': 513,
#      'paragraph': {'elements': [{'startIndex': 428,
#         'endIndex': 469,
#         'textRun': {'content': 'Add more feature and smooth out metabase ',
#          'textStyle': {}}},
#        {'startIndex': 469,
#         'endIndex': 512,
#         'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-540',
#          'textStyle': {'underline': True,
#           'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#              'green': 0.33333334,
#              'blue': 0.8}}},
#           'link': {'url': 'https://certik.atlassian.net/browse/WAT-540?atlOrigin=eyJpIjoiYWM5MmYyYzIyOThlNGFjNDg4NTgwNTBhMGI4ZThlZjkiLCJwIjoiaiJ9'}}}},
#        {'startIndex': 512,
#         'endIndex': 513,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.ppkmm014s4k2', 'textStyle': {}}}},
#     {'startIndex': 513,
#      'endIndex': 594,
#      'paragraph': {'elements': [{'startIndex': 513,
#         'endIndex': 550,
#         'textRun': {'content': '[Recurring] Label bsc null contracts ',
#          'textStyle': {}}},
#        {'startIndex': 550,
#         'endIndex': 593,
#         'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-432',
#          'textStyle': {'underline': True,
#           'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#              'green': 0.33333334,
#              'blue': 0.8}}},
#           'link': {'url': 'https://certik.atlassian.net/browse/WAT-432'}}}},
#        {'startIndex': 593,
#         'endIndex': 594,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.xqkr7uw4qp1', 'textStyle': {}}}},
#     {'startIndex': 594,
#      'endIndex': 598,
#      'paragraph': {'elements': [{'startIndex': 594,
#         'endIndex': 597,
#         'textRun': {'content': 'P2:',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1,
#              'green': 1}}}}}},
#        {'startIndex': 597,
#         'endIndex': 598,
#         'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'headingId': 'h.4zqfo634iip3',
#        'namedStyleType': 'HEADING_2',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 598,
#      'endIndex': 599,
#      'paragraph': {'elements': [{'startIndex': 598,
#         'endIndex': 599,
#         'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.pznd53c4apqf', 'textStyle': {}}}},
#     {'startIndex': 599,
#      'endIndex': 603,
#      'paragraph': {'elements': [{'startIndex': 599,
#         'endIndex': 603,
#         'textRun': {'content': 'P3:\n',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'green': 1}}}}}}],
#       'paragraphStyle': {'headingId': 'h.x8d6209vkuxx',
#        'namedStyleType': 'HEADING_2',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 603,
#      'endIndex': 650,
#      'paragraph': {'elements': [{'startIndex': 603,
#         'endIndex': 618,
#         'textRun': {'content': '[certik-python]',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 0.7137255,
#              'green': 0.84313726,
#              'blue': 0.65882355}}}}}},
#        {'startIndex': 618,
#         'endIndex': 650,
#         'textRun': {'content': ' Add multiprocess for multicall\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.fzwbzv6lpipl', 'textStyle': {}}}},
#     {'startIndex': 650,
#      'endIndex': 688,
#      'paragraph': {'elements': [{'startIndex': 650,
#         'endIndex': 688,
#         'textRun': {'content': 'Sexual Harassment Prevention Training\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.y3uu19qzwxyk', 'textStyle': {}}}},
#     {'startIndex': 688,
#      'endIndex': 723,
#      'paragraph': {'elements': [{'startIndex': 688,
#         'endIndex': 723,
#         'textRun': {'content': 'Checkout flash loan attack details\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.d05fm63wwinl', 'textStyle': {}}}},
#     {'startIndex': 723,
#      'endIndex': 756,
#      'paragraph': {'elements': [{'startIndex': 723,
#         'endIndex': 756,
#         'textRun': {'content': 'Research on mixer related issues\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.7s86sdgsdw34', 'textStyle': {}}}},
#     {'startIndex': 756,
#      'endIndex': 864,
#      'paragraph': {'elements': [{'startIndex': 756,
#         'endIndex': 863,
#         'textRun': {'content': 'https://docs.google.com/document/d/1zRI1B-H5esL-F5WU1FFZ3eVfmfHUFBi8iWGQDokUOHk/edit#heading=h.rb55kiwd5zug',
#          'textStyle': {'underline': True,
#           'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#              'green': 0.33333334,
#              'blue': 0.8}}},
#           'link': {'url': 'https://docs.google.com/document/d/1zRI1B-H5esL-F5WU1FFZ3eVfmfHUFBi8iWGQDokUOHk/edit#heading=h.rb55kiwd5zug'}}}},
#        {'startIndex': 863,
#         'endIndex': 864,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.7s86sdgsdw34',
#        'nestingLevel': 1,
#        'textStyle': {}}}},
#     {'startIndex': 864,
#      'endIndex': 931,
#      'paragraph': {'elements': [{'startIndex': 864,
#         'endIndex': 931,
#         'textRun': {'content': 'Research on getting fast transaction receipt for all transactions.\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.aidkxabsa5jp', 'textStyle': {}}}},
#     {'startIndex': 931,
#      'endIndex': 984,
#      'paragraph': {'elements': [{'startIndex': 931,
#         'endIndex': 984,
#         'textRun': {'content': 'Add a backup mechanism to contract data and results.\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#     {'startIndex': 984,
#      'endIndex': 1020,
#      'paragraph': {'elements': [{'startIndex': 984,
#         'endIndex': 1020,
#         'textRun': {'content': 'Add contract labeling system check.\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#     {'startIndex': 1020,
#      'endIndex': 1093,
#      'paragraph': {'elements': [{'startIndex': 1020,
#         'endIndex': 1093,
#         'textRun': {'content': 'Dup address and contract creator check while running the mapping script.\n',
#          'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#       'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#     {'startIndex': 1093,
#      'endIndex': 1106,
#      'paragraph': {'elements': [{'startIndex': 1093,
#         'endIndex': 1105,
#         'textRun': {'content': 'On the Side:',
#          'textStyle': {'backgroundColor': {'color': {'rgbColor': {'green': 1,
#              'blue': 1}}}}}},
#        {'startIndex': 1105,
#         'endIndex': 1106,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'headingId': 'h.hsg33kbqfibv',
#        'namedStyleType': 'HEADING_2',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1106,
#      'endIndex': 1107,
#      'paragraph': {'elements': [{'startIndex': 1106,
#         'endIndex': 1107,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1107,
#      'endIndex': 1108,
#      'paragraph': {'elements': [{'startIndex': 1107,
#         'endIndex': 1108,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1108,
#      'endIndex': 1109,
#      'paragraph': {'elements': [{'startIndex': 1108,
#         'endIndex': 1109,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1109,
#      'endIndex': 1110,
#      'paragraph': {'elements': [{'startIndex': 1109,
#         'endIndex': 1110,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1110,
#      'endIndex': 1111,
#      'paragraph': {'elements': [{'startIndex': 1110,
#         'endIndex': 1111,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1111,
#      'endIndex': 1112,
#      'paragraph': {'elements': [{'startIndex': 1111,
#         'endIndex': 1112,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1112,
#      'endIndex': 1113,
#      'paragraph': {'elements': [{'startIndex': 1112,
#         'endIndex': 1113,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1113,
#      'endIndex': 1114,
#      'paragraph': {'elements': [{'startIndex': 1113,
#         'endIndex': 1114,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1114,
#      'endIndex': 1115,
#      'paragraph': {'elements': [{'startIndex': 1114,
#         'endIndex': 1115,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1115,
#      'endIndex': 1116,
#      'paragraph': {'elements': [{'startIndex': 1115,
#         'endIndex': 1116,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1116,
#      'endIndex': 1117,
#      'paragraph': {'elements': [{'startIndex': 1116,
#         'endIndex': 1117,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1117,
#      'endIndex': 1118,
#      'paragraph': {'elements': [{'startIndex': 1117,
#         'endIndex': 1118,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1118,
#      'endIndex': 1119,
#      'paragraph': {'elements': [{'startIndex': 1118,
#         'endIndex': 1119,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1119,
#      'endIndex': 1120,
#      'paragraph': {'elements': [{'startIndex': 1119,
#         'endIndex': 1120,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}},
#     {'startIndex': 1120,
#      'endIndex': 1121,
#      'paragraph': {'elements': [{'startIndex': 1120,
#         'endIndex': 1121,
#         'textRun': {'content': '\n', 'textStyle': {}}}],
#       'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#        'direction': 'LEFT_TO_RIGHT'}}}]},
#   'documentStyle': {'background': {'color': {}},
#    'pageNumberStart': 1,
#    'marginTop': {'magnitude': 72, 'unit': 'PT'},
#    'marginBottom': {'magnitude': 72, 'unit': 'PT'},
#    'marginRight': {'magnitude': 72, 'unit': 'PT'},
#    'marginLeft': {'magnitude': 72, 'unit': 'PT'},
#    'pageSize': {'height': {'magnitude': 792, 'unit': 'PT'},
#     'width': {'magnitude': 612, 'unit': 'PT'}},
#    'marginHeader': {'magnitude': 36, 'unit': 'PT'},
#    'marginFooter': {'magnitude': 36, 'unit': 'PT'},
#    'useCustomHeaderFooterMargins': True},
#   'namedStyles': {'styles': [{'namedStyleType': 'NORMAL_TEXT',
#      'textStyle': {'bold': False,
#       'italic': False,
#       'underline': False,
#       'strikethrough': False,
#       'smallCaps': False,
#       'backgroundColor': {},
#       'foregroundColor': {'color': {'rgbColor': {}}},
#       'fontSize': {'magnitude': 11, 'unit': 'PT'},
#       'weightedFontFamily': {'fontFamily': 'Arial', 'weight': 400},
#       'baselineOffset': 'NONE'},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'alignment': 'START',
#       'lineSpacing': 115,
#       'direction': 'LEFT_TO_RIGHT',
#       'spacingMode': 'COLLAPSE_LISTS',
#       'spaceAbove': {'unit': 'PT'},
#       'spaceBelow': {'unit': 'PT'},
#       'borderBetween': {'color': {},
#        'width': {'unit': 'PT'},
#        'padding': {'unit': 'PT'},
#        'dashStyle': 'SOLID'},
#       'borderTop': {'color': {},
#        'width': {'unit': 'PT'},
#        'padding': {'unit': 'PT'},
#        'dashStyle': 'SOLID'},
#       'borderBottom': {'color': {},
#        'width': {'unit': 'PT'},
#        'padding': {'unit': 'PT'},
#        'dashStyle': 'SOLID'},
#       'borderLeft': {'color': {},
#        'width': {'unit': 'PT'},
#        'padding': {'unit': 'PT'},
#        'dashStyle': 'SOLID'},
#       'borderRight': {'color': {},
#        'width': {'unit': 'PT'},
#        'padding': {'unit': 'PT'},
#        'dashStyle': 'SOLID'},
#       'indentFirstLine': {'unit': 'PT'},
#       'indentStart': {'unit': 'PT'},
#       'indentEnd': {'unit': 'PT'},
#       'keepLinesTogether': False,
#       'keepWithNext': False,
#       'avoidWidowAndOrphan': True,
#       'shading': {'backgroundColor': {}}}},
#     {'namedStyleType': 'HEADING_1',
#      'textStyle': {'fontSize': {'magnitude': 20, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 20, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 6, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'HEADING_2',
#      'textStyle': {'bold': False, 'fontSize': {'magnitude': 16, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 18, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 6, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'HEADING_3',
#      'textStyle': {'bold': False,
#       'foregroundColor': {'color': {'rgbColor': {'red': 0.2627451,
#          'green': 0.2627451,
#          'blue': 0.2627451}}},
#       'fontSize': {'magnitude': 14, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 16, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'HEADING_4',
#      'textStyle': {'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#          'green': 0.4,
#          'blue': 0.4}}},
#       'fontSize': {'magnitude': 12, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 14, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'HEADING_5',
#      'textStyle': {'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#          'green': 0.4,
#          'blue': 0.4}}},
#       'fontSize': {'magnitude': 11, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 12, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'HEADING_6',
#      'textStyle': {'italic': True,
#       'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#          'green': 0.4,
#          'blue': 0.4}}},
#       'fontSize': {'magnitude': 11, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'magnitude': 12, 'unit': 'PT'},
#       'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'TITLE',
#      'textStyle': {'fontSize': {'magnitude': 26, 'unit': 'PT'}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'unit': 'PT'},
#       'spaceBelow': {'magnitude': 3, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}},
#     {'namedStyleType': 'SUBTITLE',
#      'textStyle': {'italic': False,
#       'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#          'green': 0.4,
#          'blue': 0.4}}},
#       'fontSize': {'magnitude': 15, 'unit': 'PT'},
#       'weightedFontFamily': {'fontFamily': 'Arial', 'weight': 400}},
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'spaceAbove': {'unit': 'PT'},
#       'spaceBelow': {'magnitude': 16, 'unit': 'PT'},
#       'keepLinesTogether': True,
#       'keepWithNext': True}}]},
#   'lists': {'kix.1b7p1g77o21m': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.4qwx7dxwi0dt': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.53qqx1rmcjet': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.7s86sdgsdw34': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.8dghcfksjel7': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.aidkxabsa5jp': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.d05fm63wwinl': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.fzwbzv6lpipl': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.l0blopbdvim9': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
# ...
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.h4hu0dfkvce9': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.nchygm621y3': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.rp811sw2lojf': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.suchg0b23r7x': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.w28nzqaubdju': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}},
#    'kix.yn3npojqj579': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%0',
#        'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#        'indentStart': {'magnitude': 36, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%1',
#        'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#        'indentStart': {'magnitude': 72, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%2',
#        'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#        'indentStart': {'magnitude': 108, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%3',
#        'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#        'indentStart': {'magnitude': 144, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%4',
#        'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#        'indentStart': {'magnitude': 180, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%5',
#        'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#        'indentStart': {'magnitude': 216, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%6',
#        'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#        'indentStart': {'magnitude': 252, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%7',
#        'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#        'indentStart': {'magnitude': 288, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1},
#       {'bulletAlignment': 'START',
#        'glyphSymbol': '-',
#        'glyphFormat': '%8',
#        'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#        'indentStart': {'magnitude': 324, 'unit': 'PT'},
#        'textStyle': {'underline': False},
#        'startNumber': 1}]}}},
#   'revisionId': 'ALm37BWRfNF9fleEJgAUUZoVyQ4DbT3CQWI92dpE2Z0ZxUGPwS_GYA40XDudqe6lus_xpuqh_5yR4GFPUcf_4Q',
#   'suggestionsViewMode': 'SUGGESTIONS_INLINE',
#   'documentId': '1HB1QSN_-d6UdagtEATH2hAGKbMZ4IkSulJopoZIRP-U'}]

# %%
docs[0]#['body']['content'][1]['paragraph']['elements'][0]['textRun']
# Out:
# {'title': 'Daily Workflow November 5 2021',
#  'body': {'content': [{'endIndex': 1,
#     'sectionBreak': {'sectionStyle': {'columnSeparatorStyle': 'NONE',
#       'contentDirection': 'LEFT_TO_RIGHT',
#       'sectionType': 'CONTINUOUS'}}},
#    {'startIndex': 1,
#     'endIndex': 32,
#     'paragraph': {'elements': [{'startIndex': 1,
#        'endIndex': 32,
#        'textRun': {'content': 'Daily Workflow November 5 2021\n',
#         'textStyle': {'bold': True,
#          'backgroundColor': {'color': {'rgbColor': {'red': 0.2901961,
#             'green': 0.5254902,
#             'blue': 0.9098039}}},
#          'foregroundColor': {'color': {'rgbColor': {'red': 1,
#             'green': 1,
#             'blue': 1}}},
#          'fontSize': {'magnitude': 24, 'unit': 'PT'}}}}],
#      'paragraphStyle': {'headingId': 'h.10qpii93ne17',
#       'namedStyleType': 'TITLE',
#       'alignment': 'CENTER',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 32,
#     'endIndex': 33,
#     'paragraph': {'elements': [{'startIndex': 32,
#        'endIndex': 33,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 33,
#     'endIndex': 37,
#     'paragraph': {'elements': [{'startIndex': 33,
#        'endIndex': 36,
#        'textRun': {'content': 'P0:',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1}}}}}},
#       {'startIndex': 36,
#        'endIndex': 37,
#        'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'headingId': 'h.t9wb2be2yvuu',
#       'namedStyleType': 'HEADING_2',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 37,
#     'endIndex': 54,
#     'paragraph': {'elements': [{'startIndex': 37,
#        'endIndex': 54,
#        'textRun': {'content': 'Tanuj Interview \n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.8dghcfksjel7', 'textStyle': {}}}},
#    {'startIndex': 54,
#     'endIndex': 98,
#     'paragraph': {'elements': [{'startIndex': 54,
#        'endIndex': 98,
#        'textRun': {'content': 'Update airflow certik-python to new version\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.8dghcfksjel7', 'textStyle': {}}}},
#    {'startIndex': 98,
#     'endIndex': 173,
#     'paragraph': {'elements': [{'startIndex': 98,
#        'endIndex': 122,
#        'textRun': {'content': 'Simple Flask Python app ', 'textStyle': {}}},
#       {'startIndex': 122,
#        'endIndex': 143,
#        'textRun': {'content': 'in docker to wrap the',
#         'textStyle': {'strikethrough': True}}},
#       {'startIndex': 143,
#        'endIndex': 144,
#        'textRun': {'content': ' ', 'textStyle': {}}},
#       {'startIndex': 144,
#        'endIndex': 173,
#        'textRun': {'content': 'semiautomatic labeling tool \n',
#         'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.1b7p1g77o21m', 'textStyle': {}}}},
#    {'startIndex': 173,
#     'endIndex': 225,
#     'paragraph': {'elements': [{'startIndex': 173,
#        'endIndex': 225,
#        'textRun': {'content': 'Switch cloud stored files into storing in snowflake\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.1b7p1g77o21m',
#       'nestingLevel': 1,
#       'textStyle': {}}}},
#    {'startIndex': 225,
#     'endIndex': 269,
#     'paragraph': {'elements': [{'startIndex': 225,
#        'endIndex': 268,
#        'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-459',
#         'textStyle': {'underline': True,
#          'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#             'green': 0.33333334,
#             'blue': 0.8}}},
#          'link': {'url': 'https://certik.atlassian.net/browse/WAT-459'}}}},
#       {'startIndex': 268,
#        'endIndex': 269,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.1b7p1g77o21m',
#       'nestingLevel': 1,
#       'textStyle': {}}}},
#    {'startIndex': 269,
#     'endIndex': 364,
#     'paragraph': {'elements': [{'startIndex': 269,
#        'endIndex': 283,
#        'textRun': {'content': 'Auto Labeling ', 'textStyle': {}}},
#       {'startIndex': 283,
#        'endIndex': 326,
#        'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-488',
#         'textStyle': {'underline': True,
#          'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#             'green': 0.33333334,
#             'blue': 0.8}}},
#          'link': {'url': 'https://certik.atlassian.net/browse/WAT-488'}}}},
#       {'startIndex': 326,
#        'endIndex': 364,
#        'textRun': {'content': 'Manuall labeling changed back to Andy\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.1b7p1g77o21m', 'textStyle': {}}}},
#    {'startIndex': 364,
#     'endIndex': 368,
#     'paragraph': {'elements': [{'startIndex': 364,
#        'endIndex': 367,
#        'textRun': {'content': 'P1:',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1,
#             'green': 0.6}}}}}},
#       {'startIndex': 367,
#        'endIndex': 368,
#        'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'headingId': 'h.9rqt2uhz0aq8',
#       'namedStyleType': 'HEADING_2',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 368,
#     'endIndex': 389,
#     'paragraph': {'elements': [{'startIndex': 368,
#        'endIndex': 388,
#        'textRun': {'content': 'Certik-python readme', 'textStyle': {}}},
#       {'startIndex': 388,
#        'endIndex': 389,
#        'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.53qqx1rmcjet', 'textStyle': {}}}},
#    {'startIndex': 389,
#     'endIndex': 428,
#     'paragraph': {'elements': [{'startIndex': 389,
#        'endIndex': 428,
#        'textRun': {'content': 'Learn about low level evm instructions\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.wrz2nfbs9sij', 'textStyle': {}}}},
#    {'startIndex': 428,
#     'endIndex': 513,
#     'paragraph': {'elements': [{'startIndex': 428,
#        'endIndex': 469,
#        'textRun': {'content': 'Add more feature and smooth out metabase ',
#         'textStyle': {}}},
#       {'startIndex': 469,
#        'endIndex': 512,
#        'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-540',
#         'textStyle': {'underline': True,
#          'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#             'green': 0.33333334,
#             'blue': 0.8}}},
#          'link': {'url': 'https://certik.atlassian.net/browse/WAT-540?atlOrigin=eyJpIjoiYWM5MmYyYzIyOThlNGFjNDg4NTgwNTBhMGI4ZThlZjkiLCJwIjoiaiJ9'}}}},
#       {'startIndex': 512,
#        'endIndex': 513,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.ppkmm014s4k2', 'textStyle': {}}}},
#    {'startIndex': 513,
#     'endIndex': 594,
#     'paragraph': {'elements': [{'startIndex': 513,
#        'endIndex': 550,
#        'textRun': {'content': '[Recurring] Label bsc null contracts ',
#         'textStyle': {}}},
#       {'startIndex': 550,
#        'endIndex': 593,
#        'textRun': {'content': 'https://certik.atlassian.net/browse/WAT-432',
#         'textStyle': {'underline': True,
#          'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#             'green': 0.33333334,
#             'blue': 0.8}}},
#          'link': {'url': 'https://certik.atlassian.net/browse/WAT-432'}}}},
#       {'startIndex': 593,
#        'endIndex': 594,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.xqkr7uw4qp1', 'textStyle': {}}}},
#    {'startIndex': 594,
#     'endIndex': 598,
#     'paragraph': {'elements': [{'startIndex': 594,
#        'endIndex': 597,
#        'textRun': {'content': 'P2:',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 1,
#             'green': 1}}}}}},
#       {'startIndex': 597,
#        'endIndex': 598,
#        'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'headingId': 'h.4zqfo634iip3',
#       'namedStyleType': 'HEADING_2',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 598,
#     'endIndex': 599,
#     'paragraph': {'elements': [{'startIndex': 598,
#        'endIndex': 599,
#        'textRun': {'content': '\n', 'textStyle': {'strikethrough': True}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.pznd53c4apqf', 'textStyle': {}}}},
#    {'startIndex': 599,
#     'endIndex': 603,
#     'paragraph': {'elements': [{'startIndex': 599,
#        'endIndex': 603,
#        'textRun': {'content': 'P3:\n',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'green': 1}}}}}}],
#      'paragraphStyle': {'headingId': 'h.x8d6209vkuxx',
#       'namedStyleType': 'HEADING_2',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 603,
#     'endIndex': 650,
#     'paragraph': {'elements': [{'startIndex': 603,
#        'endIndex': 618,
#        'textRun': {'content': '[certik-python]',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'red': 0.7137255,
#             'green': 0.84313726,
#             'blue': 0.65882355}}}}}},
#       {'startIndex': 618,
#        'endIndex': 650,
#        'textRun': {'content': ' Add multiprocess for multicall\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.fzwbzv6lpipl', 'textStyle': {}}}},
#    {'startIndex': 650,
#     'endIndex': 688,
#     'paragraph': {'elements': [{'startIndex': 650,
#        'endIndex': 688,
#        'textRun': {'content': 'Sexual Harassment Prevention Training\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.y3uu19qzwxyk', 'textStyle': {}}}},
#    {'startIndex': 688,
#     'endIndex': 723,
#     'paragraph': {'elements': [{'startIndex': 688,
#        'endIndex': 723,
#        'textRun': {'content': 'Checkout flash loan attack details\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.d05fm63wwinl', 'textStyle': {}}}},
#    {'startIndex': 723,
#     'endIndex': 756,
#     'paragraph': {'elements': [{'startIndex': 723,
#        'endIndex': 756,
#        'textRun': {'content': 'Research on mixer related issues\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.7s86sdgsdw34', 'textStyle': {}}}},
#    {'startIndex': 756,
#     'endIndex': 864,
#     'paragraph': {'elements': [{'startIndex': 756,
#        'endIndex': 863,
#        'textRun': {'content': 'https://docs.google.com/document/d/1zRI1B-H5esL-F5WU1FFZ3eVfmfHUFBi8iWGQDokUOHk/edit#heading=h.rb55kiwd5zug',
#         'textStyle': {'underline': True,
#          'foregroundColor': {'color': {'rgbColor': {'red': 0.06666667,
#             'green': 0.33333334,
#             'blue': 0.8}}},
#          'link': {'url': 'https://docs.google.com/document/d/1zRI1B-H5esL-F5WU1FFZ3eVfmfHUFBi8iWGQDokUOHk/edit#heading=h.rb55kiwd5zug'}}}},
#       {'startIndex': 863,
#        'endIndex': 864,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.7s86sdgsdw34',
#       'nestingLevel': 1,
#       'textStyle': {}}}},
#    {'startIndex': 864,
#     'endIndex': 931,
#     'paragraph': {'elements': [{'startIndex': 864,
#        'endIndex': 931,
#        'textRun': {'content': 'Research on getting fast transaction receipt for all transactions.\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.aidkxabsa5jp', 'textStyle': {}}}},
#    {'startIndex': 931,
#     'endIndex': 984,
#     'paragraph': {'elements': [{'startIndex': 931,
#        'endIndex': 984,
#        'textRun': {'content': 'Add a backup mechanism to contract data and results.\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#    {'startIndex': 984,
#     'endIndex': 1020,
#     'paragraph': {'elements': [{'startIndex': 984,
#        'endIndex': 1020,
#        'textRun': {'content': 'Add contract labeling system check.\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#    {'startIndex': 1020,
#     'endIndex': 1093,
#     'paragraph': {'elements': [{'startIndex': 1020,
#        'endIndex': 1093,
#        'textRun': {'content': 'Dup address and contract creator check while running the mapping script.\n',
#         'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'}},
#      'bullet': {'listId': 'kix.4qwx7dxwi0dt', 'textStyle': {}}}},
#    {'startIndex': 1093,
#     'endIndex': 1106,
#     'paragraph': {'elements': [{'startIndex': 1093,
#        'endIndex': 1105,
#        'textRun': {'content': 'On the Side:',
#         'textStyle': {'backgroundColor': {'color': {'rgbColor': {'green': 1,
#             'blue': 1}}}}}},
#       {'startIndex': 1105,
#        'endIndex': 1106,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'headingId': 'h.hsg33kbqfibv',
#       'namedStyleType': 'HEADING_2',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1106,
#     'endIndex': 1107,
#     'paragraph': {'elements': [{'startIndex': 1106,
#        'endIndex': 1107,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1107,
#     'endIndex': 1108,
#     'paragraph': {'elements': [{'startIndex': 1107,
#        'endIndex': 1108,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1108,
#     'endIndex': 1109,
#     'paragraph': {'elements': [{'startIndex': 1108,
#        'endIndex': 1109,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1109,
#     'endIndex': 1110,
#     'paragraph': {'elements': [{'startIndex': 1109,
#        'endIndex': 1110,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1110,
#     'endIndex': 1111,
#     'paragraph': {'elements': [{'startIndex': 1110,
#        'endIndex': 1111,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1111,
#     'endIndex': 1112,
#     'paragraph': {'elements': [{'startIndex': 1111,
#        'endIndex': 1112,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1112,
#     'endIndex': 1113,
#     'paragraph': {'elements': [{'startIndex': 1112,
#        'endIndex': 1113,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1113,
#     'endIndex': 1114,
#     'paragraph': {'elements': [{'startIndex': 1113,
#        'endIndex': 1114,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1114,
#     'endIndex': 1115,
#     'paragraph': {'elements': [{'startIndex': 1114,
#        'endIndex': 1115,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1115,
#     'endIndex': 1116,
#     'paragraph': {'elements': [{'startIndex': 1115,
#        'endIndex': 1116,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1116,
#     'endIndex': 1117,
#     'paragraph': {'elements': [{'startIndex': 1116,
#        'endIndex': 1117,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1117,
#     'endIndex': 1118,
#     'paragraph': {'elements': [{'startIndex': 1117,
#        'endIndex': 1118,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1118,
#     'endIndex': 1119,
#     'paragraph': {'elements': [{'startIndex': 1118,
#        'endIndex': 1119,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1119,
#     'endIndex': 1120,
#     'paragraph': {'elements': [{'startIndex': 1119,
#        'endIndex': 1120,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}},
#    {'startIndex': 1120,
#     'endIndex': 1121,
#     'paragraph': {'elements': [{'startIndex': 1120,
#        'endIndex': 1121,
#        'textRun': {'content': '\n', 'textStyle': {}}}],
#      'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#       'direction': 'LEFT_TO_RIGHT'}}}]},
#  'documentStyle': {'background': {'color': {}},
#   'pageNumberStart': 1,
#   'marginTop': {'magnitude': 72, 'unit': 'PT'},
#   'marginBottom': {'magnitude': 72, 'unit': 'PT'},
#   'marginRight': {'magnitude': 72, 'unit': 'PT'},
#   'marginLeft': {'magnitude': 72, 'unit': 'PT'},
#   'pageSize': {'height': {'magnitude': 792, 'unit': 'PT'},
#    'width': {'magnitude': 612, 'unit': 'PT'}},
#   'marginHeader': {'magnitude': 36, 'unit': 'PT'},
#   'marginFooter': {'magnitude': 36, 'unit': 'PT'},
#   'useCustomHeaderFooterMargins': True},
#  'namedStyles': {'styles': [{'namedStyleType': 'NORMAL_TEXT',
#     'textStyle': {'bold': False,
#      'italic': False,
#      'underline': False,
#      'strikethrough': False,
#      'smallCaps': False,
#      'backgroundColor': {},
#      'foregroundColor': {'color': {'rgbColor': {}}},
#      'fontSize': {'magnitude': 11, 'unit': 'PT'},
#      'weightedFontFamily': {'fontFamily': 'Arial', 'weight': 400},
#      'baselineOffset': 'NONE'},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'alignment': 'START',
#      'lineSpacing': 115,
#      'direction': 'LEFT_TO_RIGHT',
#      'spacingMode': 'COLLAPSE_LISTS',
#      'spaceAbove': {'unit': 'PT'},
#      'spaceBelow': {'unit': 'PT'},
#      'borderBetween': {'color': {},
#       'width': {'unit': 'PT'},
#       'padding': {'unit': 'PT'},
#       'dashStyle': 'SOLID'},
#      'borderTop': {'color': {},
#       'width': {'unit': 'PT'},
#       'padding': {'unit': 'PT'},
#       'dashStyle': 'SOLID'},
#      'borderBottom': {'color': {},
#       'width': {'unit': 'PT'},
#       'padding': {'unit': 'PT'},
#       'dashStyle': 'SOLID'},
#      'borderLeft': {'color': {},
#       'width': {'unit': 'PT'},
#       'padding': {'unit': 'PT'},
#       'dashStyle': 'SOLID'},
#      'borderRight': {'color': {},
#       'width': {'unit': 'PT'},
#       'padding': {'unit': 'PT'},
#       'dashStyle': 'SOLID'},
#      'indentFirstLine': {'unit': 'PT'},
#      'indentStart': {'unit': 'PT'},
#      'indentEnd': {'unit': 'PT'},
#      'keepLinesTogether': False,
#      'keepWithNext': False,
#      'avoidWidowAndOrphan': True,
#      'shading': {'backgroundColor': {}}}},
#    {'namedStyleType': 'HEADING_1',
#     'textStyle': {'fontSize': {'magnitude': 20, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 20, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 6, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'HEADING_2',
#     'textStyle': {'bold': False, 'fontSize': {'magnitude': 16, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 18, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 6, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'HEADING_3',
#     'textStyle': {'bold': False,
#      'foregroundColor': {'color': {'rgbColor': {'red': 0.2627451,
#         'green': 0.2627451,
#         'blue': 0.2627451}}},
#      'fontSize': {'magnitude': 14, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 16, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'HEADING_4',
#     'textStyle': {'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#         'green': 0.4,
#         'blue': 0.4}}},
#      'fontSize': {'magnitude': 12, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 14, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'HEADING_5',
#     'textStyle': {'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#         'green': 0.4,
#         'blue': 0.4}}},
#      'fontSize': {'magnitude': 11, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 12, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'HEADING_6',
#     'textStyle': {'italic': True,
#      'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#         'green': 0.4,
#         'blue': 0.4}}},
#      'fontSize': {'magnitude': 11, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'magnitude': 12, 'unit': 'PT'},
#      'spaceBelow': {'magnitude': 4, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'TITLE',
#     'textStyle': {'fontSize': {'magnitude': 26, 'unit': 'PT'}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'unit': 'PT'},
#      'spaceBelow': {'magnitude': 3, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}},
#    {'namedStyleType': 'SUBTITLE',
#     'textStyle': {'italic': False,
#      'foregroundColor': {'color': {'rgbColor': {'red': 0.4,
#         'green': 0.4,
#         'blue': 0.4}}},
#      'fontSize': {'magnitude': 15, 'unit': 'PT'},
#      'weightedFontFamily': {'fontFamily': 'Arial', 'weight': 400}},
#     'paragraphStyle': {'namedStyleType': 'NORMAL_TEXT',
#      'direction': 'LEFT_TO_RIGHT',
#      'spaceAbove': {'unit': 'PT'},
#      'spaceBelow': {'magnitude': 16, 'unit': 'PT'},
#      'keepLinesTogether': True,
#      'keepWithNext': True}}]},
#  'lists': {'kix.1b7p1g77o21m': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.4qwx7dxwi0dt': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.53qqx1rmcjet': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.7s86sdgsdw34': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.8dghcfksjel7': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.aidkxabsa5jp': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.d05fm63wwinl': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.fzwbzv6lpipl': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.l0blopbdvim9': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.ppkmm014s4k2': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.pznd53c4apqf': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.wrz2nfbs9sij': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.xqkr7uw4qp1': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}},
#   'kix.y3uu19qzwxyk': {'listProperties': {'nestingLevels': [{'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%0',
#       'indentFirstLine': {'magnitude': 18, 'unit': 'PT'},
#       'indentStart': {'magnitude': 36, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%1',
#       'indentFirstLine': {'magnitude': 54, 'unit': 'PT'},
#       'indentStart': {'magnitude': 72, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%2',
#       'indentFirstLine': {'magnitude': 90, 'unit': 'PT'},
#       'indentStart': {'magnitude': 108, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%3',
#       'indentFirstLine': {'magnitude': 126, 'unit': 'PT'},
#       'indentStart': {'magnitude': 144, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%4',
#       'indentFirstLine': {'magnitude': 162, 'unit': 'PT'},
#       'indentStart': {'magnitude': 180, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%5',
#       'indentFirstLine': {'magnitude': 198, 'unit': 'PT'},
#       'indentStart': {'magnitude': 216, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%6',
#       'indentFirstLine': {'magnitude': 234, 'unit': 'PT'},
#       'indentStart': {'magnitude': 252, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%7',
#       'indentFirstLine': {'magnitude': 270, 'unit': 'PT'},
#       'indentStart': {'magnitude': 288, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1},
#      {'bulletAlignment': 'START',
#       'glyphSymbol': '-',
#       'glyphFormat': '%8',
#       'indentFirstLine': {'magnitude': 306, 'unit': 'PT'},
#       'indentStart': {'magnitude': 324, 'unit': 'PT'},
#       'textStyle': {'underline': False},
#       'startNumber': 1}]}}},
#  'revisionId': 'ALm37BVMGkEI5SYlq8f4oh5rGoZN72S5Y30ZUFeKVk9vI8YDCwdhbqCHpt1fYyRxG2MRHrmnzNPz5_SxCih2Fg',
#  'suggestionsViewMode': 'SUGGESTIONS_INLINE',
#  'documentId': '1wpNa4NLIOtpEjiLIZjY7CWptpJe8qAAjSypKGd0qT2I'}

# %%
def get_all_text_run(doc):
    runs = []
    for paragraph in doc['body']['content']:
        if 'paragraph' in paragraph.keys():
            for element in paragraph['paragraph']['elements']:
                runs.append(element['textRun'])
    return runs

# %%
def is_strike(textRun):
    return 'strikethrough' in textRun['textStyle'] and textRun['textStyle']['strikethrough']

# %%
striked_tRun = flatten([[tRun for tRun in get_all_text_run(doc) if is_strike(tRun)] for doc in docs])

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]

# %%
striked_tRun = [run['content'] for run in striked_tRun if run['content'] != '\n']

# %%
def clean_and_dedup(runs):
    return list(dict.fromkeys([t.strip() for t in runs]))

# %%
work_done = clean_and_dedup(striked_tRun)

# %%
work_done
# Out:
# ['in docker to wrap the',
#  'semiautomatic labeling tool',
#  'Sherin interview',
#  'Interview template doc',
#  'Airflow add tags to dag.',
#  'Add catch retry to certik-python multicall',
#  'Push multicall archive implementation to weitao',
#  'Add archive block_id support to multicall - modify the smart contracts. Pushed to weitao',
#  'Onboard with Weitao',
#  'Interview with Zach [prepare]',
#  'Turn script into fully functional web ui script',
#  'Check for broken things',
#  'Archive multicall meet with Noradf',
#  'Data ingestion updates',
#  'Remove ‘tether’ from fairy pool audit list',
#  'https://certik.atlassian.net/browse/WAT-540?atlOrigin=eyJpIjoiMTM5NjNlOGIzODU5NDljZWE1NDU3YTJiNDUxNmQwNmUiLCJwIjoiaiJ9']
